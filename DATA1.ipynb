# %% [markdown]
# <a href="https://colab.research.google.com/github/jumunseong99-hue/Statistics_TIL_jumu/blob/main/DATA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import tree
X = [[0, 0], [1, 1]]
Y = [0, 1]

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
#학습
clf = clf.fit(X, Y)
cif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3902288271.py in <cell line: 0>()
#       1 clf = clf.fit(X, Y)
# ----> 2 cif
#
# NameError: name 'cif' is not defined

# %%
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
clf.predict_proba([[2., 2.]])
# Out:
# array([[0., 1.]])

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
X, y = iris.data, iris.target

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
t = tree.plot_tree(clf.fit(X, y),filled=True)
